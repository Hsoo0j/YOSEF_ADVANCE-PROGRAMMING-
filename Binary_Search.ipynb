# %% [markdown]
# #Binary Search
# Given an array of integers nums which is sorted in ascending order, and an integer target, write a function to search target in nums. If target exists, then return its index. Otherwise, return -1.
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [-1,0,3,5,9,12], target = 9
# Output: 4
# Explanation: 9 exists in nums and its index is 4
# Example 2:
#
# Input: nums = [-1,0,3,5,9,12], target = 2
# Output: -1
# Explanation: 2 does not exist in nums so return -1
#
#
# Constraints:
#
# 1 <= nums.length <= 104
# -104 < nums[i], target < 104
# All the integers in nums are unique.
# nums is sorted in ascending order.

# %% [markdown]
# #1.Iterative Binary Search

# %%
def binarySearch_iterative(nums, target):
    left, right = 0, len(nums) - 1

    while left <= right:
        mid = left + (right - left) // 2
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return -1
print(binarySearch_iterative([-1,0,3,5,9,12], 9))
print(binarySearch_iterative([-1,0,3,5,9,12], 2))
# Out:
# 4
# -1

# %% [markdown]
# #2.Recursive Binary Search

# %%
def binarySearch_recursive(nums, target):
    def helper(left, right):
        if left > right:
            return -1
        mid = left + (right - left) // 2
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            return helper(mid + 1, right)
        else:
            return helper(left, mid - 1)

    return helper(0, len(nums) - 1)
print(binarySearch_recursive([-1,0,3,5,9,12], 9))
print(binarySearch_recursive([-1,0,3,5,9,12], 2))
# Out:
# 4
# -1

# %% [markdown]
# #3.Using Python’s bisect Module

# %%
import bisect

def binarySearch_bisect(nums, target):
    index = bisect.bisect_left(nums, target)
    if index < len(nums) and nums[index] == target:
        return index
    return -1
print(binarySearch_bisect([-1,0,3,5,9,12], 9))
print(binarySearch_bisect([-1,0,3,5,9,12], 2))
# Out:
# 4
# -1
