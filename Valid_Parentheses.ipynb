# %% [markdown]
# #Valid Parentheses
#
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
# Every close bracket has a corresponding open bracket of the same type.
#
#
# Example 1:
#
# Input: s = "()"
#
# Output: true
#
# Example 2:
#
# Input: s = "()[]{}"
#
# Output: true
#
# Example 3:
#
# Input: s = "(]"
#
# Output: false
#
# Example 4:
#
# Input: s = "([])"
#
# Output: true
#
# Example 5:
#
# Input: s = "([)]"
#
# Output: false
#
#
#
# Constraints:
#
# 1 <= s.length <= 104
# s consists of parentheses only '()[]{}'.

# %% [markdown]
# #No.1 Classic Stack with Mapping (O(n) time, O(n) space)

# %%
def isValid_stack(s: str) -> bool:
    stack = []
    mapping = {')': '(', '}': '{', ']': '['}

    for char in s:
        if char in mapping:
            if not stack or stack[-1] != mapping[char]:
                return False
            stack.pop()
        else:
            stack.append(char)

    return not stack
print(isValid_stack("()[]{}"))
print(isValid_stack("([)]"))
# Out:
# True
# False

# %% [markdown]
# #No.2 Stack with Early Exit and Direct Comparison

# %%
def isValid_direct(s: str) -> bool:
    stack = []
    for char in s:
        if char in '({[':
            stack.append(char)
        else:
            if not stack:
                return False
            top = stack.pop()
            if (char == ')' and top != '(') or \
               (char == '}' and top != '{') or \
               (char == ']' and top != '['):
                return False
    return not stack
print(isValid_direct("()[]{}"))
print(isValid_direct("([)]"))
# Out:
# True
# False

# %% [markdown]
# #No.3 Replace‑Based String Reduction (O(n²) worst case, O(n) space)

# %%
def isValid_replace(s: str) -> bool:
    while '()' in s or '[]' in s or '{}' in s:
        s = s.replace('()', '').replace('[]', '').replace('{}', '')
    return not s
print(isValid_replace("()[]{}"))
print(isValid_replace("([)]"))
# Out:
# True
# False
